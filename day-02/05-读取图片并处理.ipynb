# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
timg = plt.imread('timg.jpg')
plt.imshow(timg)

# %%
timg.shape
# Out:
# (399, 544, 3)

# %%
plt.imshow(timg[:, ::-1])

# %%
plt.imshow(timg[::-1, ::-1])

# %%
tim = timg[:300, 100:350]
plt.imsave('tim.jpg', tim)
tim
# Out:
# array([[[157, 151, 163],
#         [161, 155, 167],
#         [164, 158, 170],
#         ...,
#         [221, 225, 226],
#         [225, 229, 232],
#         [230, 233, 238]],
#
#        [[157, 151, 163],
#         [159, 153, 165],
#         [161, 155, 167],
#         ...,
#         [212, 216, 217],
#         [219, 223, 226],
#         [227, 230, 235]],
#
#        [[158, 152, 164],
#         [155, 149, 161],
#         [158, 152, 164],
#         ...,
#         [214, 218, 219],
#         [223, 227, 230],
#         [229, 232, 237]],
#
#        ...,
#
#        [[223, 229, 243],
#         [225, 231, 245],
#         [229, 233, 245],
#         ...,
#         [223, 222, 238],
#         [221, 223, 236],
#         [221, 225, 236]],
#
#        [[222, 228, 242],
#         [225, 231, 245],
#         [226, 232, 244],
#         ...,
#         [220, 222, 237],
#         [220, 224, 236],
#         [220, 228, 239]],
#
#        [[217, 223, 237],
#         [221, 227, 241],
#         [224, 230, 244],
# ...
